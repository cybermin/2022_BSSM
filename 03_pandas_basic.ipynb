# %% [markdown]
# <a href="https://colab.research.google.com/github/cybermin/2022_BSSM/blob/main/03_pandas_basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
#
# # **해결문제**
#
#
# 부산지역 2019~2020년 RFID기반 음식물쓰레기 배출량를 분석하시오.
#
#
# ---

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#한글 폰트 사용설치
# %config InlineBackend.figure_format = 'retina'

# !apt -qq -y install fonts-nanum
# Out:
# fonts-nanum is already the newest version (20170925-1).
# 0 upgraded, 0 newly installed, 0 to remove and 37 not upgraded.

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.font_manager as fm
fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=9)
plt.rc('font', family='NanumBarunGothic') 
mpl.font_manager._rebuild()

# %%
plt.title('한글')
plt.show()

# %% [markdown]
# ## 데이터불러오기

# %%
#pandas 라이브러리 추가
import pandas as pd

# %%
#데이터불러오기
df = pd.read_csv('/content/drive/MyDrive/BSSM/BSSM2022/data/부산RFID음식물쓰레기.csv')

# %%
df.head()
# Out:
#            일자  요일     배출량  배출량비율  배출횟수  배출횟수비율 영역코드    시도명 시군구명
# 0  2019-01-01   3  258000   3.47   188    3.35  W0Q  부산광역시   중구
# 1  2019-01-02   4  273050   3.68   200    3.56  W0Q  부산광역시   중구
# 2  2019-01-03   5  254300   3.42   196    3.49  W0Q  부산광역시   중구
# 3  2019-01-04   6  241150   3.25   182    3.24  W0Q  부산광역시   중구
# 4  2019-01-05   7  234750   3.16   192    3.42  W0Q  부산광역시   중구

# %%
df['시군구명'].unique()
# Out:
# array(['중구', '서구', '동구', '영도구', '부산진구', '동래구', '남구', '북구', '해운대구', '사하구',
#        '금정구', '강서구', '연제구', '수영구', '사상구', '기장군'], dtype=object)

# %%
#강서구의 2020년 배출량 정보를 추출하시오.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11696 entries, 0 to 11695
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   일자      11696 non-null  object
#  1   요일      11696 non-null  int64
#  2   배출량     11696 non-null  int64
#  3   배출량비율   11696 non-null  float64
#  4   배출횟수    11696 non-null  int64
#  5   배출횟수비율  11696 non-null  float64
#  6   영역코드    11696 non-null  object
#  7   시도명     11696 non-null  object
#  8   시군구명    11696 non-null  object
# dtypes: float64(2), int64(3), object(4)
# memory usage: 822.5+ KB

# %%
s = '2019-01-01'
s[:4]
# Out:
# '2019'

# %%
df['일자'].str[:4]
# Out:
# 0        2019
# 1        2019
# 2        2019
# 3        2019
# 4        2019
#          ...
# 11691    2020
# 11692    2020
# 11693    2020
# 11694    2020
# 11695    2020
# Name: 일자, Length: 11696, dtype: object

# %%
df[(df['시군구명']=='강서구') & (df['일자'].str[:4] == '2020')]
# Out:
#               일자  요일       배출량  배출량비율  배출횟수  배출횟수비율 영역코드    시도명 시군구명
# 8406  2020-01-01   4  13704300   3.55  7486    3.42  W11  부산광역시  강서구
# 8407  2020-01-02   5  12576650   3.25  7080    3.24  W11  부산광역시  강서구
# 8408  2020-01-03   6  11132750   2.88  6410    2.93  W11  부산광역시  강서구
# 8409  2020-01-04   7  11412150   2.95  6522    2.98  W11  부산광역시  강서구
# 8410  2020-01-05   1  14395050   3.73  8031    3.67  W11  부산광역시  강서구
# ...          ...  ..       ...    ...   ...     ...  ...    ...  ...
# 8767  2020-12-27   1  16429400   3.58  9133    3.50  W11  부산광역시  강서구
# 8768  2020-12-28   2  16190200   3.53  9184    3.52  W11  부산광역시  강서구
# 8769  2020-12-29   3  12343050   2.69  7444    2.85  W11  부산광역시  강서구
# 8770  2020-12-30   4  12162850   2.65  7293    2.80  W11  부산광역시  강서구
# 8771  2020-12-31   5  14713500   3.21  8609    3.30  W11  부산광역시  강서구
#
# [366 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11696 entries, 0 to 11695
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   일자      11696 non-null  object
#  1   요일      11696 non-null  int64
#  2   배출량     11696 non-null  int64
#  3   배출량비율   11696 non-null  float64
#  4   배출횟수    11696 non-null  int64
#  5   배출횟수비율  11696 non-null  float64
#  6   영역코드    11696 non-null  object
#  7   시도명     11696 non-null  object
#  8   시군구명    11696 non-null  object
# dtypes: float64(2), int64(3), object(4)
# memory usage: 822.5+ KB

# %%
df.columns
# Out:
# Index(['일자', '요일', '배출량', '배출량비율', '배출횟수', '배출횟수비율', '영역코드', '시도명', '시군구명'], dtype='object')

# %% [markdown]
# ## **열 타입 변경**
#
#
# ---
# + df.dtypes : 데이터타입 확인
# + df[열명].astype(변환타입)
#   + 정수형은 .astype(‘int’)
#   + 문자형은 .astype(‘str’)
#   + 범주형은 .astype(‘category’)
# + pd.to_numeric(열): 문자열 칼럼의 숫자형 변환
# + pd.to_datetime(열) : 날짜형식으로 변경

# %% [markdown]
# ### 시계열 자료
# * **dt 접근자** : datetime 자료형 시리즈에는 dt 접근자가 있어 datetime 자료형이 가진 몇가지 유용한 속성과 메서드를 사용
#   +  year, month, day, weekday 등의 속성을 이용하면 년, 월, 일, 요일 정보 추출
#
# dt 접근자 | 내용
# -------------------|------------------
# .dt.date         | YYYY-MM-DD(문자)
# .dt.year         | 연(4자리숫자)
# .dt.month        | 월(숫자)
# .dt.month_name() | 월(문자)
# .dt.day          | 일(숫자)
# .dt.time         | HH:MM:SS(문자)
# .dt.hour         | 시(숫자)
# .dt.minute       | 분(숫자)
# .dt.second       | 초(숫자)
# .dt.quarter       | 분기(숫자)
# .dt.day_name()  | 요일이름(문자)
# .dt.weekday       | 요일숫자(0-월, 1-화) (=dayofweek)
# .dt.weekofyear    | 연 기준 몇주째(숫자) (=week)
# .dt.dayofyear     | 연 기준 몇일째(숫자)
# .dt.days_in_month | 월 일수(숫자) (=daysinmonth)

# %%
#일자를 날짜 형식으로 변환 
df['일자'] = pd.to_datetime(df['일자'])

# %%
#변환 확인 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11696 entries, 0 to 11695
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   일자      11696 non-null  datetime64[ns]
#  1   요일      11696 non-null  int64
#  2   배출량     11696 non-null  int64
#  3   배출량비율   11696 non-null  float64
#  4   배출횟수    11696 non-null  int64
#  5   배출횟수비율  11696 non-null  float64
#  6   영역코드    11696 non-null  object
#  7   시도명     11696 non-null  object
#  8   시군구명    11696 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(3), object(3)
# memory usage: 822.5+ KB

# %%
#연도/월 추출하여 연도/월 열 추가 
df['연도'] = df['일자'].dt.year
df['월'] = df['일자'].dt.month

# %%
df.head()
# Out:
#           일자  요일     배출량  배출량비율  배출횟수  배출횟수비율 영역코드    시도명 시군구명    연도  월
# 0 2019-01-01   3  258000   3.47   188    3.35  W0Q  부산광역시   중구  2019  1
# 1 2019-01-02   4  273050   3.68   200    3.56  W0Q  부산광역시   중구  2019  1
# 2 2019-01-03   5  254300   3.42   196    3.49  W0Q  부산광역시   중구  2019  1
# 3 2019-01-04   6  241150   3.25   182    3.24  W0Q  부산광역시   중구  2019  1
# 4 2019-01-05   7  234750   3.16   192    3.42  W0Q  부산광역시   중구  2019  1

# %%
#추가 확인 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11696 entries, 0 to 11695
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   일자      11696 non-null  datetime64[ns]
#  1   요일      11696 non-null  int64
#  2   배출량     11696 non-null  int64
#  3   배출량비율   11696 non-null  float64
#  4   배출횟수    11696 non-null  int64
#  5   배출횟수비율  11696 non-null  float64
#  6   영역코드    11696 non-null  object
#  7   시도명     11696 non-null  object
#  8   시군구명    11696 non-null  object
#  9   연도      11696 non-null  int64
#  10  월       11696 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(5), object(3)
# memory usage: 1005.2+ KB

# %%
# 연도와 월을 범주형 데이터타입으로 변경
df['연도'] = df['연도'].astype('category')
df['월'] = df['월'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11696 entries, 0 to 11695
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   일자      11696 non-null  datetime64[ns]
#  1   요일      11696 non-null  int64
#  2   배출량     11696 non-null  int64
#  3   배출량비율   11696 non-null  float64
#  4   배출횟수    11696 non-null  int64
#  5   배출횟수비율  11696 non-null  float64
#  6   영역코드    11696 non-null  object
#  7   시도명     11696 non-null  object
#  8   시군구명    11696 non-null  object
#  9   연도      11696 non-null  category
#  10  월       11696 non-null  category
# dtypes: category(2), datetime64[ns](1), float64(2), int64(3), object(3)
# memory usage: 845.8+ KB

# %% [markdown]
# ## 연도별 배출량

# %%
df.head()
# Out:
#           일자  요일     배출량  배출량비율  배출횟수  배출횟수비율 영역코드    시도명 시군구명    연도  월
# 0 2019-01-01   3  258000   3.47   188    3.35  W0Q  부산광역시   중구  2019  1
# 1 2019-01-02   4  273050   3.68   200    3.56  W0Q  부산광역시   중구  2019  1
# 2 2019-01-03   5  254300   3.42   196    3.49  W0Q  부산광역시   중구  2019  1
# 3 2019-01-04   6  241150   3.25   182    3.24  W0Q  부산광역시   중구  2019  1
# 4 2019-01-05   7  234750   3.16   192    3.42  W0Q  부산광역시   중구  2019  1

# %%
import seaborn as sns

# %%
df[(df['연도']==2019) & (df['월']==3)]['배출량'].mean()
# Out:
# 12292508.622983871

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='연도', y='배출량', hue='월', data=df)
plt.title('연도별 음식물 쓰레기 배출량')
plt.axhline(y=df[(df['연도']==2019) & (df['월']==3)]['배출량'].mean(), color='r')
plt.show()

# %%
plt.figure(figsize=(10,5))
 
sns.barplot(x='월', y='배출횟수', hue='연도', data=df)
plt.title('월별 음식물쓰레기 배출횟수') 
plt.show()

# %%
plt.figure(figsize=(7,7))
 
sns.scatterplot(x='배출량', y='배출횟수', hue='연도', data=df)
plt.title('배출량과 배출횟수 관계') 
plt.show()

# %%
sns.pairplot(hue='연도', data=df)
plt.show()

# %% [markdown]
# ## **각 열의 범주형 자료 분석**
#
# + **df.drop_duplicates()** : 중복값은 모두 제거하고 유일한 값만 표시
# + **df.unique()**: 각 열 내에 유일한 값을 확인
# + **df.value_counts()** : 각 열 내에 각각의 값이 나온 횟수
# + 시리즈.map(딕션너리) : 해당 시리즈의 내용에 매핑할 값을 딕셔너리 형태로 지정

# %%
#요일자료 분석 (1-7 :일-토)
df['요일'].unique()
# Out:
# array([3, 4, 5, 6, 7, 1, 2])

# %%
df.head(2)
# Out:
#           일자  요일     배출량  배출량비율  배출횟수  배출횟수비율 영역코드    시도명 시군구명    연도  월
# 0 2019-01-01   3  258000   3.47   188    3.35  W0Q  부산광역시   중구  2019  1
# 1 2019-01-02   4  273050   3.68   200    3.56  W0Q  부산광역시   중구  2019  1

# %%
df['요일명'] = df['요일'].map({1:'일', 2:'월', 3:'화', 4:'수', 5:'목', 6:'금', 7:'토'})
df.head(2)
# Out:
#           일자  요일     배출량  배출량비율  배출횟수  배출횟수비율 영역코드    시도명 시군구명    연도  월 요일명
# 0 2019-01-01   3  258000   3.47   188    3.35  W0Q  부산광역시   중구  2019  1   화
# 1 2019-01-02   4  273050   3.68   200    3.56  W0Q  부산광역시   중구  2019  1   수

# %%
plt.figure(figsize=(10,5))
 
sns.barplot(x='요일명', y='배출횟수', hue='연도', data=df)
plt.title('요일별 음식물쓰레기 배출횟수')
plt.show()

# %%
plt.figure(figsize=(10,5))
 
sns.barplot(x='요일', y='배출횟수', hue='연도', data=df)
plt.xticks(range(7), labels=['일','월','화','수','목','금','토'])
plt.title('요일별 음식물쓰레기 배출횟수')
plt.show()

# %% [markdown]
# ## 그룹화
# * 데이터를 그룹별로 분류
# * df.groupby(인수)
#   + 열 또는 열의 리스트
#   + 행 인덱스
# * 그룹 연산 메소드
#   + size, count: 그룹 데이터의 갯수
#   + mean, median, min, max: 그룹 데이터의 평균, 중앙값, 최소, 최대
#   + sum, prod, std, var, quantile : 그룹 데이터의 합계, 곱, 표준편차, 분산, 사분위수
#   + first, last: 그룹 데이터 중 가장 첫번째 데이터와 가장 나중 데이터

# %%
#연도별 요일별 배출량 배출횟수 평균 
df[['연도','요일', '배출량', '배출횟수']].sort_values(['연도','요일'])
# Out:
#          연도  요일       배출량  배출횟수
# 5      2019   1    235300   168
# 12     2019   1    253450   186
# 19     2019   1    242900   172
# 26     2019   1    200800   126
# 33     2019   1    393400   241
# ...     ...  ..       ...   ...
# 11662  2020   7  16139660  8395
# 11669  2020   7  17781880  9158
# 11676  2020   7  16802350  8796
# 11683  2020   7  14626690  8009
# 11690  2020   7  15360480  8651
#
# [11696 rows x 4 columns]

# %%
dfg = df.groupby(['연도','요일']).mean()

# %%
dfg
# Out:
#                   배출량     배출량비율          배출횟수    배출횟수비율
# 연도   요일
# 2019 1   1.674633e+07  3.855192   9878.115385  3.585120
#      2   1.548629e+07  3.582764   9674.259615  3.517079
#      3   1.392737e+07  3.203031   9044.162736  3.271167
#      4   1.328349e+07  3.069243   8789.230769  3.182127
#      5   1.391685e+07  3.218486   9151.894231  3.310733
#      6   1.281379e+07  2.991214   8509.591346  3.105349
#      7   1.321908e+07  3.095409   8288.973558  3.042139
# 2020 1   1.797600e+07  3.881490  10787.542067  3.601538
#      2   1.556427e+07  3.377031   9974.257212  3.332284
#      3   1.500809e+07  3.238341   9937.784856  3.307825
#      4   1.435953e+07  3.113408   9643.946934  3.226521
#      5   1.427862e+07  3.100755   9523.709906  3.203691
#      6   1.403825e+07  3.056142   9379.866587  3.157993
#      7   1.456000e+07  3.190228   9256.217548  3.124002

# %%
dfg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 14 entries, (2019, 1) to (2020, 7)
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   배출량     14 non-null     float64
#  1   배출량비율   14 non-null     float64
#  2   배출횟수    14 non-null     float64
#  3   배출횟수비율  14 non-null     float64
# dtypes: float64(4)
# memory usage: 786.0 bytes

# %%
dfg = dfg[['배출량', '배출횟수']]

# %%
dfg
# Out:
#                   배출량          배출횟수
# 연도   요일
# 2019 1   1.674633e+07   9878.115385
#      2   1.548629e+07   9674.259615
#      3   1.392737e+07   9044.162736
#      4   1.328349e+07   8789.230769
#      5   1.391685e+07   9151.894231
#      6   1.281379e+07   8509.591346
#      7   1.321908e+07   8288.973558
# 2020 1   1.797600e+07  10787.542067
#      2   1.556427e+07   9974.257212
#      3   1.500809e+07   9937.784856
#      4   1.435953e+07   9643.946934
#      5   1.427862e+07   9523.709906
#      6   1.403825e+07   9379.866587
#      7   1.456000e+07   9256.217548

# %%
dfg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 14 entries, (2019, 1) to (2020, 7)
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   배출량     14 non-null     float64
#  1   배출횟수    14 non-null     float64
# dtypes: float64(2)
# memory usage: 562.0 bytes

# %%
#인덱스 재설정 
dfg = dfg.reset_index()
dfg
# Out:
#       연도  요일           배출량          배출횟수
# 0   2019   1  1.674633e+07   9878.115385
# 1   2019   2  1.548629e+07   9674.259615
# 2   2019   3  1.392737e+07   9044.162736
# 3   2019   4  1.328349e+07   8789.230769
# 4   2019   5  1.391685e+07   9151.894231
# 5   2019   6  1.281379e+07   8509.591346
# 6   2019   7  1.321908e+07   8288.973558
# 7   2020   1  1.797600e+07  10787.542067
# 8   2020   2  1.556427e+07   9974.257212
# 9   2020   3  1.500809e+07   9937.784856
# 10  2020   4  1.435953e+07   9643.946934
# 11  2020   5  1.427862e+07   9523.709906
# 12  2020   6  1.403825e+07   9379.866587
# 13  2020   7  1.456000e+07   9256.217548

# %%
#2019, 2020년 자료 분리 
dfg2019 = dfg[dfg['연도']==2019] 
dfg2020 = dfg[dfg['연도']==2020]

# %%
dfg2019
# Out:
#      연도  요일           배출량         배출횟수
# 0  2019   1  1.674633e+07  9878.115385
# 1  2019   2  1.548629e+07  9674.259615
# 2  2019   3  1.392737e+07  9044.162736
# 3  2019   4  1.328349e+07  8789.230769
# 4  2019   5  1.391685e+07  9151.894231
# 5  2019   6  1.281379e+07  8509.591346
# 6  2019   7  1.321908e+07  8288.973558

# %%
dfg2020
# Out:
#       연도  요일           배출량          배출횟수
# 7   2020   1  1.797600e+07  10787.542067
# 8   2020   2  1.556427e+07   9974.257212
# 9   2020   3  1.500809e+07   9937.784856
# 10  2020   4  1.435953e+07   9643.946934
# 11  2020   5  1.427862e+07   9523.709906
# 12  2020   6  1.403825e+07   9379.866587
# 13  2020   7  1.456000e+07   9256.217548

# %%
#2019, 2020년 요일을 인덱스로 설정 
dfg2019 =  dfg2019.set_index('요일')
dfg2020 =  dfg2020.set_index('요일')

# %%
dfg2019
# Out:
#       연도           배출량         배출횟수
# 요일
# 1   2019  1.674633e+07  9878.115385
# 2   2019  1.548629e+07  9674.259615
# 3   2019  1.392737e+07  9044.162736
# 4   2019  1.328349e+07  8789.230769
# 5   2019  1.391685e+07  9151.894231
# 6   2019  1.281379e+07  8509.591346
# 7   2019  1.321908e+07  8288.973558

# %%
dfg2020
# Out:
#       연도           배출량          배출횟수
# 요일
# 1   2020  1.797600e+07  10787.542067
# 2   2020  1.556427e+07   9974.257212
# 3   2020  1.500809e+07   9937.784856
# 4   2020  1.435953e+07   9643.946934
# 5   2020  1.427862e+07   9523.709906
# 6   2020  1.403825e+07   9379.866587
# 7   2020  1.456000e+07   9256.217548

# %% [markdown]
# ## 데이터프레임 합치기
# + pd.concat()()  데이터프레임을 말그대로 물리적으로 이어 붙여주는 함수
#   + axis : 연결 방향 (0-행, 1-열)
#   + join : 방식 (outer : 합집합, inner :교집합)
# ```
# pd.concat([연결할 데이터프레임명리스트],axis=1, join='inner')
# ```

# %%
#2019, 2020년 열로 합치기 
dfgw = pd.concat([dfg2019, dfg2020], axis=1, join='inner') 
dfgw
# Out:
#       연도           배출량         배출횟수    연도           배출량          배출횟수
# 요일
# 1   2019  1.674633e+07  9878.115385  2020  1.797600e+07  10787.542067
# 2   2019  1.548629e+07  9674.259615  2020  1.556427e+07   9974.257212
# 3   2019  1.392737e+07  9044.162736  2020  1.500809e+07   9937.784856
# 4   2019  1.328349e+07  8789.230769  2020  1.435953e+07   9643.946934
# 5   2019  1.391685e+07  9151.894231  2020  1.427862e+07   9523.709906
# 6   2019  1.281379e+07  8509.591346  2020  1.403825e+07   9379.866587
# 7   2019  1.321908e+07  8288.973558  2020  1.456000e+07   9256.217548

# %%
dfgw.iloc[0, 1]
# Out:
# 16746325.889423076

# %%
#2019, 2020년 배출량과 배출횟수 자료만 추출 
dfgw = dfgw.iloc[:, [1,2,4,5]]
dfgw
# Out:
#              배출량         배출횟수           배출량          배출횟수
# 요일
# 1   1.674633e+07  9878.115385  1.797600e+07  10787.542067
# 2   1.548629e+07  9674.259615  1.556427e+07   9974.257212
# 3   1.392737e+07  9044.162736  1.500809e+07   9937.784856
# 4   1.328349e+07  8789.230769  1.435953e+07   9643.946934
# 5   1.391685e+07  9151.894231  1.427862e+07   9523.709906
# 6   1.281379e+07  8509.591346  1.403825e+07   9379.866587
# 7   1.321908e+07  8288.973558  1.456000e+07   9256.217548

# %%
#열명변경 : '2019배출량', '2019배출횟수','2020배출량', '2020배출횟수'
dfgw.columns = ['2019배출량', '2019배출횟수','2020배출량', '2020배출횟수'] 
dfgw
# Out:
#          2019배출량     2019배출횟수       2020배출량      2020배출횟수
# 요일
# 1   1.674633e+07  9878.115385  1.797600e+07  10787.542067
# 2   1.548629e+07  9674.259615  1.556427e+07   9974.257212
# 3   1.392737e+07  9044.162736  1.500809e+07   9937.784856
# 4   1.328349e+07  8789.230769  1.435953e+07   9643.946934
# 5   1.391685e+07  9151.894231  1.427862e+07   9523.709906
# 6   1.281379e+07  8509.591346  1.403825e+07   9379.866587
# 7   1.321908e+07  8288.973558  1.456000e+07   9256.217548

# %%
#배출량과 배출횟수 차이 
dfgw['배출량차이'] =  dfgw['2020배출량'] - dfgw['2019배출량']
dfgw['배출횟수차이'] =  dfgw['2020배출횟수'] - dfgw['2019배출횟수']
dfgw
# Out:
#          2019배출량     2019배출횟수  ...         배출량차이      배출횟수차이
# 요일                             ...
# 1   1.674633e+07  9878.115385  ...  1.229672e+06  909.426683
# 2   1.548629e+07  9674.259615  ...  7.797948e+04  299.997596
# 3   1.392737e+07  9044.162736  ...  1.080712e+06  893.622120
# 4   1.328349e+07  8789.230769  ...  1.076042e+06  854.716165
# 5   1.391685e+07  9151.894231  ...  3.617643e+05  371.815675
# 6   1.281379e+07  8509.591346  ...  1.224459e+06  870.275240
# 7   1.321908e+07  8288.973558  ...  1.340916e+06  967.243990
#
# [7 rows x 6 columns]

# %%
dfgw
# Out:
#          2019배출량     2019배출횟수  ...         배출량차이      배출횟수차이
# 요일                             ...
# 1   1.674633e+07  9878.115385  ...  1.229672e+06  909.426683
# 2   1.548629e+07  9674.259615  ...  7.797948e+04  299.997596
# 3   1.392737e+07  9044.162736  ...  1.080712e+06  893.622120
# 4   1.328349e+07  8789.230769  ...  1.076042e+06  854.716165
# 5   1.391685e+07  9151.894231  ...  3.617643e+05  371.815675
# 6   1.281379e+07  8509.591346  ...  1.224459e+06  870.275240
# 7   1.321908e+07  8288.973558  ...  1.340916e+06  967.243990
#
# [7 rows x 6 columns]

# %%
plt.plot(dfgw['2019배출량'])
plt.title('2019배출량')
plt.show()

# %%
plt.plot(dfgw['2019배출횟수'])
plt.title('2019배출횟수')
plt.xticks(range(1,8), labels=['일','월','화','수','목','금','토'])
plt.show()

# %% [markdown]
# # 함수(Function)
# + 특정 기능을 하나로 묶어서 따로 관리하기 위해 사용
#  - 반복되는 내용을 효율적으로 처리
#  - 코드의 가독성을 높임
#
# + 함수의 종류
#  - 내장함수 : 파이썬에서 기본으로 제공하는 함수
#  - 모듈함수 : import를 해서 가져다가 사용할 수 있는 함수
#  - 사용자정의함수 : 사용자가 함수를 직접

# %% [markdown]
# ## **사용자 정의 함수**
# * **사용자 정의 함수 구조**
# ```python
# def 함수명(매개변수1, 매개변수2....) :
#     명령문
#     명령문
#
#   return 반환값1 ....
# ```
#   + 가변매개변수
#     + 튜플 형식  : *args
#     + 딕션너리 형식 : **args
#
#
# * 함수 호출
#   + 반환값이 없을 경우 : 함수명(인수)
#   + 반환값이 있을 경우 : 변수명 = 함수명(인수)
#
#
# * **스크립트 파일이 메인 프로그램으로 사용될 때와 모듈로 사용될 때를 구분하기 위한 용도**
# ```
# if __name__ == '__main__':
#      메인 수행문
# ```

# %%
dfgw.head(2)
# Out:
#          2019배출량     2019배출횟수  ...         배출량차이      배출횟수차이
# 요일                             ...
# 1   1.674633e+07  9878.115385  ...  1.229672e+06  909.426683
# 2   1.548629e+07  9674.259615  ...  7.797948e+04  299.997596
#
# [2 rows x 6 columns]

# %%
#각 열의 그래프 그리기 함수
def dfgw_plot(col) :
  plt.plot(dfgw[col])
  
  plt.title(col)
  plt.xticks(range(1,8), labels=['일','월','화','수','목','금','토'])
  plt.show()

# %%
#각 열의 그래프 그리기 
for col in dfgw.columns:
  dfgw_plot(col)
